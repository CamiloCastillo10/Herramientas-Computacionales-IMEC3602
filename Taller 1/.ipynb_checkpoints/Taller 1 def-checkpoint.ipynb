# %% [markdown]
# Taller 1.
#
# Herraminetas Computacionales
#
# Camilo Santiago Castillo Lasso
#
# 201412050
#
# Se importan las librerias que seran usadas

# %%
import os
import pandas as pd
from scipy import stats as st
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Funcion que retorna la serie IDEAM
#
# Parametros: nombre de la ciudad
#
# retorno: serie_IDEAM

# %%
base_dir = os.path.join( '.','data')
output_dir = os.path.join( '.','output')
def serie_IDEAM(ciudad):
    serie_csvIDEAM=os.path.join(base_dir,ciudad,'IDEAM'+'.csv')
    serie_IDEAM=pd.read_csv(serie_csvIDEAM, sep=';',encoding='latin-1')
    return serie_IDEAM

# %% [markdown]
# Funcion que retorna la serie NREL
#
# Parametros: nombre de la ciudad
#
# retorno: serie_NREL

# %%
def serie_NREL(ciudad):
    serie_csvNREL=os.path.join(base_dir,ciudad,'NREL'+'.csv')
    serie_NREL=pd.read_csv(serie_csvNREL, sep=';',encoding='latin-1')
    return serie_NREL

# %% [markdown]
# Funcion que retorna las series IDEAM y NREL.
#
# Parametros: nombre ciudad.
#
# retorna: serie_IDEAM, serie_NREL

# %%
def darSeries(ciudad):
    return serie_IDEAM(ciudad), serie_NREL(ciudad)

# %% [markdown]
# Funcion que retorna la energia total en $kWh/m^2$ para cada mes de la serie horaria.
#
# Parametros: serie horaria.
#
# Retorna: serie con el total de energia y dias por mes

# %%
def ghi_mensual(serie_horaria):
    agnos = sorted(serie_horaria['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "DIAS", "GHImes"])
    for agno in agnos:
        for mes in range(1,13):
            
            nombre_energia = list(serie_horaria)[-1]
            dias = sorted(serie_horaria[(serie_horaria['AÑO'] == agno) &
                        (serie_horaria['MES'] == mes)]["DIA"].unique())
            
            ghi_mes = serie_horaria.loc[((serie_horaria["AÑO"] == agno)
                            & (serie_horaria["MES"] == mes)),
                                        nombre_energia].sum()/1000
            
            ghi_dict = {"AÑO":agno, "MES":mes, "DIAS":dias[-1],
                        "GHImes":ghi_mes}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
            
    return ghi_df

# %% [markdown]
# Funcion que calcula el promedio de energia diario mensual para la serie.
#
# Parametros: Serie mensual.
#
# Retorna: Serie con el promedio diaria mensual de energia en $kWh/m^2$
# .

# %%
def ghi_dia(serie_ghi_mensual):
    agnos = sorted(serie_ghi_mensual['AÑO'].unique())
    ghi_df = pd.DataFrame(columns=["AÑO", "MES", "GHIdiario"])
    for agno in agnos:
        for mes in range(1,13):
            
            dias = serie_ghi_mensual.loc[((serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes))
                                         ,"DIAS"].item()
            
            ghi_diario = serie_ghi_mensual.loc[(
                (serie_ghi_mensual["AÑO"] == agno)
                            & (serie_ghi_mensual["MES"] == mes)),
                "GHImes"].item()/dias
            
            ghi_dict = {"AÑO":agno, "MES":mes, "GHIdiario":ghi_diario}
            ghi_df = ghi_df.append(ghi_dict, ignore_index=True)
            
    return ghi_df

# %% [markdown]
# Funcion que calcula el promedio de energia diario mensual a partir de una serie horaria.
#
# Parametros: serie horaria
#
# Retorna: serie con el promedio diario mensual.

# %%
def promDiaMen(serieHoraria):
        
    ghiMensual=ghi_mensual(serieHoraria)
    ghiDiario=ghi_dia(ghiMensual)
    datos=sorted(ghiDiario['GHIdiario'])
    return datos

# %% [markdown]
# Funcion que realiza una grafica de la distribucion de la energia mensual promedio a partir de una serie horaria.
#
# Parametros: serie horaria, nombre de la serie, color de la serie

# %%
def graficarDistribucionDeEnergia(serieHoraria, nombre, color, datosIdeam):

    datos=promDiaMen(serieHoraria)
    pylab.xlabel("Datos")
    pylab.ylabel("Energía/Energía Base IDEAM")
    numdatos = range(len(datos))
    pylab.plot(numdatos,datos/datosIdeam[0],color, label=nombre)
    pylab.legend(loc='upper left')

# %% [markdown]
# Prueba de el funcionamineto de las funciones planteadas.

# %%
ideam, nrel=darSeries('Valledupar')
datosIdeam=promDiaMen(ideam)
graficarDistribucionDeEnergia(ideam, 'IDEAM','-k',datosIdeam)
graficarDistribucionDeEnergia(nrel, 'NREL','-g',datosIdeam)

# %% [markdown]
# Funcion que calcula la enerergia que se obtendra el 99% de las veces a partir de una serie horaria.
#
# Parametros: serie horaria.
#
# Retorna: valor de la ENFICC

# %%
def ENFICC(serieHoraria):
    percentil=0.01
    
    ghiMensual=ghi_mensual(serieHoraria)
    ghiDiario=ghi_dia(ghiMensual)
    
    enficc=ghiDiario.quantile(q=percentil, numeric_only=True)['GHIdiario']
    return enficc

# %% [markdown]
# Funcion que corta de un dataFrame los meses de un intervalo de años indicado
#
# Parametros: serie, año Inicio, año Fin, mes de inicio, mes de fin
#
# Retorna: serie cortada

# %%
def cortar(serie, aqnoInicio, aqnoFin, mesesInicio, mesesFin):
        if(aqnoInicio == aqnoFin) & (mesesFin >= mesesInicio):
            serie = serie[(serie['AÑO']==aqnoInicio) & (serie['MES']>=mesesInicio) & (serie['MES']<=mesesFin)]
            
        if(aqnoInicio != aqnoFin):
            serie_1 = serie[(serie['AÑO']==aqnoInicio) & (serie['MES']>=mesesInicio)]
            serie_2= serie[(serie['AÑO']>aqnoInicio)&(serie['AÑO']<aqnoFin)]
            serie_3 = serie[(serie['AÑO']==aqnoFin) & (serie['MES']<=mesesFin)]
            serie = pd.concat([serie_1, serie_2, serie_3])
            
        if(aqnoFin < aqnoInicio):
            
            serie = 'El año final no puede ser menor al año inicial'
        return serie

# %% [markdown]
# Funcion que calcula la media y la desviacion estandar poblacional a partir de una columna de datos.
#
# Parametros: columna de la serie de datos.
#
# Retorna: media y desviacion estandar poblacional.

# %%
def prom_desv(ColumnaSerie):
    return np.mean(ColumnaSerie), np.std(ColumnaSerie)

# %% [markdown]
# Funcion que ajusta una serie larga a partir de una serie corta de refencia.
#
# Parametros: serie corta, serie larga
#
# Retorna: serie larga con el ajuste de curva realizado

# %%
def mcp(seCorta, seLarga, seLargaCort):
    mu_y, desv_y=prom_desv(seCorta)
    mu_x, desv_x=prom_desv(seLargaCort)
    y=(mu_y-(desv_y/desv_x)*mu_x)+(desv_y/desv_x)*seLarga
    y=y.clip(lower=0)
    return y

# %% [markdown]
# Funcion que calcula el enficc de ideam, nrel y la serie corregida a partir de las especificaciones de fecha que se hacen para el ajuste de la serie corregida
#
# -Parametros: ciudad, año inicio, año fin, mes inicio, mes fin
#
# -Retorna:enficc ideam, enficc nrel, enficc serie corregida

# %%
def comENFICC(ciudad,aqnoInicio,aqnoFin,mesesInicio,mesesFin):
    ideam,nrel=darSeries(ciudad)
    enficcIdema=ENFICC(ideam)
    enficcNrel=ENFICC(nrel)
    ideamCor=cortar(ideam,aqnoInicio,aqnoFin,mesesInicio,mesesFin)
    nrelCor=cortar(nrel,aqnoInicio,aqnoFin,mesesInicio,mesesFin)
    serie=mcp(ideamCor['IDEAM'],nrel['NREL'],nrelCor['NREL'])
    nuevaSerie=nrel
    nuevaSerie['NREL']=serie
    enficcSerie=ENFICC(nuevaSerie)
    return enficcIdema,enficcNrel,enficcSerie

# %% [markdown]
# Funcion que a partir de un nombre de ciudad y un numero de meses grafica la distribucion de energia corregida, del ideam y del nrel.
#
# Parametros: nombre ciudad,añoInicio del corte, año de fin del corte, mdes de inicio del corte y mes de fin del corte.

# %%
def graficarPrediccion(ciudad,aqnoInicioEmpare,aqnoFinEmpare, aqnoInicio, aqnoFin, mesesInicio, mesesFin, nombreSerie,color):
    ideam,nrelD=darSeries(ciudad)
    nrel=cortar(nrelD,aqnoInicioEmpare,aqnoFinEmpare,1,12)
    ideamCortada=cortar(ideam,aqnoInicio,aqnoFin,mesesInicio,mesesFin)['IDEAM'] 
    cCorregida=mcp(ideamCortada,nrel['NREL'],cortar(nrel,aqnoInicio,aqnoFin,mesesInicio,mesesFin)['NREL'])
    datosIdeam=promDiaMen(ideam)
    graficarDistribucionDeEnergia(nrel,'vieja','-r',datosIdeam)
    graficarDistribucionDeEnergia(ideam,'IDEAM','-k',datosIdeam)
    nuevaSerie=nrel
    nuevaSerie['NREL']=cCorregida
    graficarDistribucionDeEnergia(nuevaSerie,nombreSerie,color,datosIdeam)

# %% [markdown]
# Funcion que calcula el mean bias(MB) a partir de dos series cortadas
#
# Parametros: serie satelital cortada, serie de tierra cortada
#
# retorna: MB, serie nrel para calcular el mean bias relativo

# %%
def MB(serieSat,serieTier):

    N=len(serieSat)
    rest=array(serieSat)-array(serieTier)
    suma=sum(rest)
    return suma/N

# %% [markdown]
# Funcion que calcula el mean bias realtivo (rMB) a partir de dos series cortadas
#
# Parametros: serie satelital cortada, serie tierra cortada
#
# retorna: rMB

# %%
def rMB(serieSat,serieTier):
    mb=MB(serieSat,serieTier)
    suma=sum(serieTier)
    N=len(serieTier)
    div=suma/N
    r=mb/div
    return r

# %% [markdown]
# Funcion que calcula el root mean square deviation (RMSD)
#
# Parametros: ciudad, año, mes de inicio, mes de fin
#
# retorna: RMSD, serie nrel

# %%
def RMSD(serieSat,serieTierra):

    N=len(serieSat)
    rest=(array(serieSat)-array(serieTierra))**2
    suma=sum(rest)
    div=suma/N
    sq=div**(.5)
    return sq

# %% [markdown]
# Funcion que calcula el root mean square deviation relativo(RMSD)
#
# Parametros: ciudad, año, mes de inicio, mes de fin
#
# retorna: rRMSD

# %%
def rRMSD(serieSat,serieTier):
    rmsd=RMSD(serieSat,serieTier)
    suma=sum(serieTier)
    N=len(serieTier)
    div=suma/N
    r=rmsd/div
    return r

# %% [markdown]
# Funcion que calcula el KSI en un año y lapso de meses igual para una ciudad
#
# Parametros: ciudad, año, mes inicio, mes de fin

# %%
def KSI(serieSat,serieTier):

    return st.ks_2samp(serieSat,serieTier)

# %% [markdown]
# Funcion que calcula el rMB de ideam, nrel y la serie corregida a partir de las especificaciones de fecha que se hacen para el ajuste de la serie corregida
#
# -Parametros: ciudad, (año inicio, año fin, mes inicio, mes fin (el lapso de tiempo debe de ser de 10 años)),año de Inicio de la Correccion,año de Fin Correccion, meses Icinio Correccion, meses Fin Correccion
#
# -Retorna:rMB nrel-ideam, rMB corregida-ideam

# %%
def comRMB(ciudad,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor,aqnoInicio,aqnoFin,mesesIcinio,mesesFin):
    ideam,nrel=darSeries(ciudad)
    nrelCor10=cortar(nrel,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    ideamCor10=cortar(ideam,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rmbNrel=rMB(nrelCor10['NREL'],ideamCor10['IDEAM'])
    
    nrelCor=cortar(nrel,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    ideamCor=cortar(ideam,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    
    seCorregida=mcp(ideamCor['IDEAM'],nrel['NREL'],nrelCor['NREL'])
    nuevaSerie=nrel
    nuevaSerie['NREL']=seCorregida
    seCortada=cortar(nuevaSerie,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rmbCorregida=rMB(seCortada['NREL'],ideamCor10['IDEAM'])
    return rmbNrel,rmbCorregida

# %% [markdown]
# Funcion que calcula el RMSD de ideam, nrel y la serie corregida a partir de las especificaciones de fecha que se hacen para el ajuste de la serie corregida
#
# -Parametros: ciudad, (año inicio, año fin, mes inicio, mes fin (el lapso de tiempo debe de ser de 10 años)),año de Inicio de la Correccion,año de Fin Correccion, meses Icinio Correccion, meses Fin Correccion
#
# -Retorna:RMSD nrel-ideam, RMSD corregida-ideam

# %%
def comRMSD(ciudad,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor,añoInicio,añoFin,mesesIcinio,mesesFin):
    ideam,nrel=darSeries(ciudad)
    nrelCor10=cortar(nrel,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    ideamCor10=cortar(ideam,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rmsdNrel=RMSD(nrelCor10['NREL'],ideamCor10['IDEAM'])
    
    nrelCor=cortar(nrel,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    ideamCor=cortar(ideam,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    
    seCorregida=mcp(ideamCor['IDEAM'],nrel['NREL'],nrelCor['NREL'])
    nuevaSerie=nrel
    nuevaSerie['NREL']=seCorregida
    seCortada=cortar(nuevaSerie,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rmsdCorregida=RMSD(seCortada['NREL'],ideamCor10['IDEAM'])
    return rmsdNrel,rmsdCorregida

# %% [markdown]
# Funcion que calcula el rRMSD de ideam, nrel y la serie corregida a partir de las especificaciones de fecha que se hacen para el ajuste de la serie corregida
#
# -Parametros: ciudad, (año inicio, año fin, mes inicio, mes fin (el lapso de tiempo debe de ser de 10 años)),año de Inicio de la Correccion,año de Fin Correccion, meses Icinio Correccion, meses Fin Correccion
#
# -Retorna:rRMSD nrel-ideam, rRMSD corregida-ideam

# %%
def comrRMSD(ciudad,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor,aqnoInicio,aqnoFin,mesesIcinio,mesesFin):
    ideam,nrel=darSeries(ciudad)
    nrelCor10=cortar(nrel,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    ideamCor10=cortar(ideam,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rrmsdNrel=rRMSD(nrelCor10['NREL'],ideamCor10['IDEAM'])
    
    nrelCor=cortar(nrel,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    ideamCor=cortar(ideam,aqnoInicioCor,aqnoFinCor,mesesIcinioCor,mesesFinCor)
    
    seCorregida=mcp(ideamCor['IDEAM'],nrel['NREL'],nrelCor['NREL'])
    nuevaSerie=nrel
    nuevaSerie['NREL']=seCorregida
    seCortada=cortar(nuevaSerie,aqnoInicio,aqnoFin,mesesIcinio,mesesFin)
    rrmsdCorregida=rRMSD(seCortada['NREL'],ideamCor10['IDEAM'])
    return rrmsdNrel,rrmsdCorregida

# %% [markdown]
# Ahora ya planteadas las funciones que se van a usar se procede a realizar el analisis por cada ciudad
#
# Para el caso de Barranquilla se cuenta tanto con informacion satelital y en tierra de 6 años (2010-2015): Como dice la norma es necesario poseer informacion de minimo 3 meses en tierra para realizar la prediccion de la produccion de energia, por esta razon se tomaron 30 muestras de 3 meses en el lapso de tiempo del que poseemos informacion para ver el efecto que puede traer en la prediccion.

# %%
a=[2010,2011,2012,2013,2014,2015]
b=[1,3,5,7,9]

B='Barranquilla'
IniB=2010
FinB=2015

# %%
for aqno in a:
    figure(aqno-2009)
    v=[0,1,2,3,4]
    for i in v:   
        graficarPrediccion(B,IniB,FinB,aqno,aqno,1+i*2,3+i*2,str(aqno)+'/0'+str(i*2+1)+'-'+str(aqno)+'/0'+str(3+i*2),'C'+str(i))
        plt.title(str(aqno))

# %% [markdown]
# En las graficas anteriores podemos notar que para el caso de barranquilla el metodo de correcion MCP dependiendo del momento del año en el que se tomen los 3 meses de muetras la serie corregida es muy diferente. Tambien se puede notar que en los años 2014 y 2015 es donde mas ocurre esta variacion con respeto al metodo MCP.

# %%
ideam,nrel,cor=comENFICC(B,2010,2010,1,3)

m=['01-03','03-05','05-07','07-09','09-11']
print('En '+B+' para la serie IDEAM se obtuvo un valor de ENFICC='+str(ideam)+' y para la serie NREL se obtuvo un valor de ENFICC='+str(nrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        ideam,nrel,cor=comENFICC(B,aqno,aqno,1+2*i,3+2*i)
        v[i]=cor/ideam
    pylab.plot(m,v,'C'+str(aqno-2010), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("Enficc corregida/Enficc IDEAM")
pylab.legend(loc='lower left')
# Out:
# En Barranquilla para la serie IDEAM se obtuvo un valor de ENFICC=4.16059025817 y para la serie NREL se obtuvo un valor de ENFICC=4.60594683333

# %% [markdown]
# Con esta grafica se puede reafirmar que el metodo MCP no es muy bueno para estimar la energia que se puede producir el 1% de las veces en el caso de Barranquilla, ya que como podemos ver segun la muestra que tomemos esta puede variar entre el 10% menor y 20% mayor a la enficc reportada a partir de los datos ideam.

# %%
rMBnrel,rMb=comRMB(B,2010,2015,1,12,2010,2010,1,3)
print('En '+B+' entre la serie IDEAM y la serie NREL existe un rMB='+str(rMBnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rMBcor=comRMB(B,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rMBcor/rMBnrel
    pylab.plot(m,v,'C'+str(aqno-2010), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rMB corregida/rMB NREL")
pylab.legend(loc='upper left')
# Out:
# En Barranquilla entre la serie IDEAM y la serie NREL existe un rMB=0.0795319066106

# %% [markdown]
# Si analizamos la forma que toman las lineas en esta grafica es exactamente el reflejo en el eje X de la la grafica anterior, por lo cual tambien nos indica la dispersion que tienen los datos aunque se les haya realizado la correccion.

# %%
rRMSDnrel,rMb=comrRMSD(B,2010,2015,1,12,2010,2010,1,3)
print('En '+B+' entre la serie IDEAM y la serie NREL existe un rRMSD='+str(rRMSDnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rRMSDcor=comrRMSD(B,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rRMSDcor/rRMSDnrel
    pylab.plot(m,v,'C'+str(aqno-2010), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rRMSD corregida/rRMSD NREL")
pylab.legend(loc='upper left')
# Out:
# En Barranquilla entre la serie IDEAM y la serie NREL existe un rRMSD=0.624065776552

# %% [markdown]
# Este grafico la la raiz de la diferencia cuadrada de la serie de datos corregida respecto a la serie ideam, como podemos notar para el caso de Barranquilla la serie tiende a aumentar su error disminuye si se realiza la correccion con una muestra de los primeros mese del año

# %% [markdown]
# Para el caso de Medelliin se cuenta tanto con informacion satelital y en tierra de 10 años (2006-2015): Como dice la norma es necesario poseer informacion de minimo 3 meses en tierra para realizar la prediccion de la produccion de energia, por esta razon se tomaron 30 muestras de 3 meses en el lapso de tiempo del que poseemos informacion para ver el efecto que puede traer en la prediccion

# %%
a=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
m=['03-05','05-07','07-09']
M='Medellin'
IniM=a[0]
FinM=a[-1]

# %%
for aqno in a:
    figure(aqno-2005)
    v=[0,1,2]
    for i in v:   
        graficarPrediccion(M,IniM,FinM,aqno,aqno,3+i*2,5+i*2,str(aqno)+'/0'+str(i*2+3)+'-'+str(aqno)+'/0'+str(5+i*2),'C'+str(i))
        plt.title(str(aqno))

# %% [markdown]
# En estas graficas podemos observar que en el caso de Medellin la correccion por lo general funciona, a excepcion del año 2015 donde todas las series corregidas parecen presentar un error grande con respecto a la serie ideam.

# %%
ideam,nrel,cor=comENFICC(M,a[0],a[0],1,3)

m=['01-03','03-05','05-07','07-09','09-11']
print('En '+M+' para la serie IDEAM se obtuvo un valor de ENFICC='+str(ideam)+' y para la serie NREL se obtuvo un valor de ENFICC='+str(nrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        ideam,nrel,cor=comENFICC(M,aqno,aqno,1+2*i,3+2*i)
        v[i]=cor/ideam
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("Enficc corregida/Enficc IDEAM")
pylab.legend(loc='lower left')
# Out:
# En Medellin para la serie IDEAM se obtuvo un valor de ENFICC=3.53519358791 y para la serie NREL se obtuvo un valor de ENFICC=4.32600282796

# %% [markdown]
# En esta grafica podemos observar que en el caso de medellin la prediccion de la ENFICC se realiza con un error alrededor del 6% lo cual es aceptable. a excepcion de las muestras del 2015, las cuales dan errores mayores.

# %%
rMBnrel,rMb=comRMB(M,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+M+' entre la serie IDEAM y la serie NREL existe un rMB='+str(rMBnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rMBcor=comRMB(M,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rMBcor/rMBnrel
    pylab.plot(m,v,'C'+str(aqno-2006), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rMB corregida/rMB NREL")
pylab.legend(loc='upper left')
# Out:
# En Medellin entre la serie IDEAM y la serie NREL existe un rMB=0.24921477313

# %% [markdown]
# Esta grafica nos indica que en el caso de Medellin el error de sesgo medio relativo por lo menos se ve disminuido en un 50% con respecto al error de sesgo medio que existe en entre los datos nrel e ideam.

# %%
rRMSDnrel,rMb=comrRMSD(M,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+M+' entre la serie IDEAM y la serie NREL existe un rRMSD='+str(rRMSDnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rRMSDcor=comrRMSD(M,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rRMSDcor/rRMSDnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rRMSD corregida/rRMSD NREL")
pylab.legend(loc='upper left')
# Out:
# En Medellin entre la serie IDEAM y la serie NREL existe un rRMSD=0.769559311402

# %% [markdown]
# En esta grafica podemos observar que para el caso de Medellin  entre los mese 5 y 9 por lo general es donde se ve mayormente reducido el error RMSD, al contrario de Barranquilla donde este error se ve aumentado en estos mismos meses.

# %% [markdown]
# Para el caso de Sucre se cuenta tanto con informacion satelital y en tierra de 10 años (2006-2015): Como dice la norma es necesario poseer informacion de minimo 3 meses en tierra para realizar la prediccion de la produccion de energia, por esta razon se tomaron 30 muestras de 3 meses en el lapso de tiempo del que poseemos informacion para ver el efecto que puede traer en la prediccion.

# %%
a=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
m=['03-05','05-07','07-09']
S='Sucre'
IniS=a[0]
FinS=a[-1]

# %%
for aqno in a:
    figure(aqno-2005)
    v=[0,1,2]
    for i in v:   
        graficarPrediccion(S,IniS,FinS,aqno,aqno,3+i*2,5+i*2,str(aqno)+'/0'+str(i*2+3)+'-'+str(aqno)+'/0'+str(5+i*2),'C'+str(i))
        plt.title(str(aqno))

# %% [markdown]
# En esta grafica podemos notar que para el caso de Sucre la correccion por lo general funciona, debido a que las series parecen presentar errores bajos, a excepcion de las correcciones hechas con muestras de los años 2011 y 2012, ya que estas parecen mostrar un mayor error.

# %%
ideam,nrel,cor=comENFICC(S,a[0],a[0],1,3)

m=['01-03','03-05','05-07','07-09','09-11']
print('En '+S+' para la serie IDEAM se obtuvo un valor de ENFICC='+str(ideam)+' y para la serie NREL se obtuvo un valor de ENFICC='+str(nrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        ideam,nrel,cor=comENFICC(S,aqno,aqno,1+2*i,3+2*i)
        v[i]=cor/ideam
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("Enficc corregida/Enficc IDEAM")
pylab.legend(loc='lower left')
# Out:
# En Sucre para la serie IDEAM se obtuvo un valor de ENFICC=2.37964439946 y para la serie NREL se obtuvo un valor de ENFICC=4.8399985

# %% [markdown]
# Esta grafica nos muestra que se hace una reduccion significativa del error, ya que la diferencia porcentual que hay entre la ENFICC reportada por la serie nrel y la ENFICC reportada por la serie ideam es alrededor del 200%, mientras que la mayoria de las series corregidas presentas un error alrededor de 80%. Cabe resaltar que las correccion hechas en el año 2011 a partir de la mitad del año comienzan a diminuir la diferencia porcentual con la ENFICC ideam.

# %%
rMBnrel,rMb=comRMB(M,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+S+' entre la serie IDEAM y la serie NREL existe un rMB='+str(rMBnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rMBcor=comRMB(S,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rMBcor/rMBnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rMB corregida/rMB NREL")
pylab.legend(loc='upper left')
# Out:
# En Sucre entre la serie IDEAM y la serie NREL existe un rMB=0.24921477313

# %% [markdown]
# Con esta grafica podemos notar que en el caso de Sucre la correccion reducce casi al maximo el error por rMB, a excepcionde los años 2011 y 2012, en los cuales, en el primero el error aumenta a partir de la mitad del año, y en el segundo el error oscila con un error maximo de 10%.

# %%
rRMSDnrel,rMb=comrRMSD(M,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+S+' entre la serie IDEAM y la serie NREL existe un rRMSD='+str(rRMSDnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rRMSDcor=comrRMSD(S,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rRMSDcor/rRMSDnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rRMSD corregida/rRMSD NREL")
pylab.legend(loc='upper left')
# Out:
# En Sucre entre la serie IDEAM y la serie NREL existe un rRMSD=0.769559311402

# %% [markdown]
# Esta grafica nos muestra que para el caso de Sucre el error rRMSD se ve reducido en un 25% en la mayoria de los años estudiados, a excepcion de los años 2011 y 2012, donde este tipo de error mencionado se ve aumentado debido a la correccion.

# %% [markdown]
# Para el caso de Valledupar se cuenta tanto con informacion satelital y en tierra de 10 años (2006-2015): Como dice la norma es necesario poseer informacion de minimo 3 meses en tierra para realizar la prediccion de la produccion de energia, por esta razon se tomaron 30 muestras de 3 meses en el lapso de tiempo del que poseemos informacion para ver el efecto que puede traer en la prediccion.

# %%
a=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
m=['03-05','05-07','07-09']
V='Valledupar'
IniV=a[0]
FinV=a[-1]

# %%
for aqno in a:
    figure(aqno-2005)
    v=[0,1,2]
    for i in v:   
        graficarPrediccion(V,IniV,FinV,aqno,aqno,3+i*2,5+i*2,str(aqno)+'/0'+str(i*2+3)+'-'+str(aqno)+'/0'+str(5+i*2),'C'+str(i))
        plt.title(str(aqno))

# %% [markdown]
# Para el caso de Valledupar, podemos observar que en las 10 graficas de arriba que el metodo no es muy efectivo, ya que solo se ve una reduccion de error significativa cuando se realiza la correcion en años especificos.

# %%
ideam,nrel,cor=comENFICC(V,a[0],a[0],1,3)

m=['01-03','03-05','05-07','07-09','09-11']
print('En '+V+' para la serie IDEAM se obtuvo un valor de ENFICC='+str(ideam)+' y para la serie NREL se obtuvo un valor de ENFICC='+str(nrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        ideam,nrel,cor=comENFICC(V,aqno,aqno,1+2*i,3+2*i)
        v[i]=cor/ideam
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("Enficc corregida/Enficc IDEAM")
pylab.legend(loc='lower left')
# Out:
# En Valledupar para la serie IDEAM se obtuvo un valor de ENFICC=4.56900737661 y para la serie NREL se obtuvo un valor de ENFICC=5.06265316667

# %% [markdown]
# Se puede observar que en esta grafica la correcion que se realizo para las serie de Valledupar muestran reduccion en el error, esta correccion segun el caso varia entre 5% por encima y por debajo del valor de ENFICC reportado por la serie ideam. Exceptuando las correcciones hechas con muestras del año 2015 que muestran un error de 10% y 15% con respecto al valor de valor de ENFICC reportado por la serie ideam

# %%
rMBnrel,rMb=comRMB(V,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+V+' entre la serie IDEAM y la serie NREL existe un rMB='+str(rMBnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rMBcor=comRMB(V,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rMBcor/rMBnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rMB corregida/rMB NREL")
pylab.legend(loc='upper left')
# Out:
# En Valledupar entre la serie IDEAM y la serie NREL existe un rMB=0.24921477313

# %% [markdown]
# En esta grafica podemos observar que el rMB disminuye en un 50% para la mayoria series corregidas.

# %%
rRMSDnrel,rMb=comrRMSD(V,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+V+' entre la serie IDEAM y la serie NREL existe un rRMSD='+str(rRMSDnrel))
for aqno in a:
    v=[0,1,2,3,4]
    for i in v:
        x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno,aqno,1+2*i,3+2*i)
        v[i]=rRMSDcor/rRMSDnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rRMSD corregida/rRMSD NREL")
pylab.legend(loc='upper left')
# Out:
# En Valledupar entre la serie IDEAM y la serie NREL existe un rRMSD=0.488903427962

# %% [markdown]
# En esta grafica se puede detallar que el rRMDS aumenta para la mayoria de las series corregidas, este aumento es alrededor de 20% con respeto al rRMSD que hay entre la serie ideam y nrel original.

# %% [markdown]
# Debido a que Valledupar es la ciudad en la que la correccion tuvo menor efecto se estudiara en esta el efecto que podria tener el variar la cantidad de meses de la muestra, esto se hace con el fin de observar si representa alguna mejora poseer mayor cantidad de datos en tierra para realizar una buena correccion de los datos.

# %%
a=[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
V='Valledupar'
IniV=a[0]
FinV=a[-1]

# %%
for aqno in a:
    figure(aqno-2005)

    graficarPrediccion(V,IniV,FinV,aqno,aqno,4,7,str(aqno)+'/04'+'-'+str(aqno)+'/07','C'+str(0))
    graficarPrediccion(V,IniV,FinV,aqno-1,aqno,9,2,str(aqno-1)+'/09'+'-'+str(aqno)+'/02','C'+str(1))
    graficarPrediccion(V,IniV,FinV,aqno,aqno,1,8,str(aqno)+'/01'+'-'+str(aqno)+'/08','C'+str(2))
    graficarPrediccion(V,IniV,FinV,aqno-1,aqno,2,2,str(aqno-1)+'/02'+'-'+str(aqno)+'/02','C'+str(3))
    graficarPrediccion(V,IniV,FinV,aqno-2,aqno,10,3,str(aqno-2)+'/10'+'-'+str(aqno)+'/03','C'+str(4))
    plt.title(str(aqno))

# %% [markdown]
# Comparando con las graficas de la correcion hecha a partir de muestras de tres mese podemos observar una mejora sustancial

# %%
a=[2008,2009,2010,2011,2012,2013,2014,2015]

# %%
ideam,nrel,cor=comENFICC(V,a[0],a[0],1,3)

m=['01-08','02-02','04-07','09-02','10-03']
print('En '+V+' para la serie IDEAM se obtuvo un valor de ENFICC='+str(ideam)+' y para la serie NREL se obtuvo un valor de ENFICC='+str(nrel))
for aqno in a:
    v=[0,0,0,0,0]


    ideam,nrel,cor=comENFICC(V,aqno,aqno,1,8)
    v[0]=cor/ideam
    ideam,nrel,cor=comENFICC(V,aqno-1,aqno,2,2)
    v[1]=cor/ideam
    ideam,nrel,cor=comENFICC(V,aqno,aqno,4,7)
    v[2]=cor/ideam
    ideam,nrel,cor=comENFICC(V,aqno-1,aqno,9,2)
    v[3]=cor/ideam
    ideam,nrel,cor=comENFICC(V,aqno-2,aqno,10,3)
    v[4]=cor/ideam
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("Enficc corregida/Enficc IDEAM")
pylab.legend(loc='lower left')
# Out:
# En Valledupar para la serie IDEAM se obtuvo un valor de ENFICC=4.56900737661 y para la serie NREL se obtuvo un valor de ENFICC=5.06265316667

# %% [markdown]
# Para el caso de Valledupar, si se varia el tamaño de la muestra de datos en tierra para realizar la correccion no cambia sustancialmente la eficacia al momento de poder predecir el primer percentil de la ENFICC.

# %%
rRMSDnrel,rMb=comrRMSD(V,a[0],a[-1],1,12,a[0],a[0],1,3)
print('En '+V+' entre la serie IDEAM y la serie NREL existe un rMB='+str(rMBnrel))
for aqno in a:
    v=[0,0,0,0,0]
    x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno,aqno,1,8)
    v[0]=rRMSDcor/rRMSDnrel
    x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno-1,aqno,2,2)
    v[1]=rRMSDcor/rRMSDnrel
    x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno,aqno,4,7)
    v[2]=rRMSDcor/rRMSDnrel
    x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno-1,aqno,9,2)
    v[3]=rRMSDcor/rRMSDnrel
    x,rRMSDcor=comrRMSD(V,a[0],a[-1],1,12,aqno-2,aqno,10,3)
    v[4]=rRMSDcor/rRMSDnrel
    pylab.plot(m,v,'C'+str(aqno-a[0]), label=str(aqno))
    pylab.xlabel("Intervalo de meses")
    pylab.ylabel("rMB corregida/rMB NREL")
pylab.legend(loc='upper left')
# Out:
# En Valledupar entre la serie IDEAM y la serie NREL existe un rMB=0.130649395941

# %% [markdown]
# Conclusiones:
# - El metodo de correccion MCP es bueno, ya que posee la ventaja de ser facil de aplicar, pero tal vez no sea el mejor metodo que se pueda usar para este tipo de problema.
# - La longitud de la muestra de datos no influye en mayor medida en la correccion de la serie con el metodo MCP
